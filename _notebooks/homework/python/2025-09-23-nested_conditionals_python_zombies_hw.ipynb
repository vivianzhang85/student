# %% [raw]
# ---
# layout: post
# title: Conditionals in Python by Ctrl-Zombies
# description: Conditionals homework in Python
# permalink: /viviannestedconditionalspythonhw
# Author: Aneesh Deevi, Moiz Lukmani, Perry Say
# ---

# %% [markdown]
# # Nested Conditionals Python Homework
# ---
# ## Python Popcorn Hack

# %%
weather = "rainy"
temperature = 50

# Fill in the blanks!
if weather == "sunny":
    if temperature > 70:  # fill in missing operator
        print("Perfect day to go outside!")  # fill in missing string
    else:
        print("Could be a bit chilly, wear a jacket!")
else:
    if weather == "rainy":   # fill in missing word
        print("Don't forget your umbrella!")
    else:
        print("Might be cloudy, enjoy your day!")  # fill in missing string
# Out:
# Don't forget your umbrella!

# %% [markdown]
# ### Part A: Python Practice
# Write a code cell that helps decide what type of transportation someone should take.
#
# - If the **weather** is `"rainy"`:
#   - If they have an umbrella -> print `"Take the bus!"`
#   - If they don’t -> print `"Call an Uber!"`
# - If the **weather** is `"sunny"`:
#   - If they have a bike -> print `"Bike!"`
#   - If they don’t -> print `"Walk!"`
#
# ---
#
# ### Example Starter Code

# %%
weather = "sunny"
has_umbrella = False
has_bike = True

# %% [markdown]
# ## My work

# %%
# Example starter variables
weather = "sunny"
has_umbrella = False
has_bike = True

# Decision logic
if weather == "rainy":
    if has_umbrella:
        print("Take the bus!")
    else:
        print("Call an Uber!")
elif weather == "sunny":
    if has_bike:
        print("Bike!")
    else:
        print("Walk!")
# Out:
# Bike!

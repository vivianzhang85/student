# %% [markdown]
# ---
# layout: post
# title: teaching basics
# permalink: /tests
# ---

# %% [markdown]
# # AP CSP – 10 Minute Problem Set
# ## Big Idea 3.5: Boolean Expressions and Logic
#
# ### 1. Boolean Basics (1 min)
# Circle True or False:
# a) A Boolean value can only be `True` or `False`.
# b) The expression `7 == 8` evaluates to `True`.
# c) The expression `5 < 10` evaluates to `True`.
#
# ---
#
# ### 2. Relational Operators (1 min)
# Fill in the blank with the correct relational operator (`==, !=, >, <, >=, <=`):
# a) `8 ___ 8` → True
# b) `12 ___ 15` → True
# c) `5 ___ 2` → False
#
# ---
#
# ### 3. Modulo Operator (1 min)
# Write a Boolean expression that checks if a variable `num` is **even**.
#
# ---
#
# ### 4. Logical Operators (2 min)
# Determine if each expression is True or False when `x = 12` and `y = 5`.
#
# a) `(x > 10) and (y > 10)` → ______
# b) `(x < 20) or (y > 10)` → ______
# c) `not (y < 7)` → ______
#
# ---
#
# ### 5. Scenario Practice (2 min)
# Write Boolean expressions for the following:
#
# a) You can go out if you finished your homework **and** your test score is at least 80.
#
# b) You can leave your umbrella at home if it is **not** cloudy **and** the temperature is greater than 75.
#
# ---
#
# ### 6. AP-Style Question (3 min)
# In a country, a person must be at least 16 years old to drive a car and at least 18 years old to vote.
# The variable `age` represents a person’s age.
#
# Which of the following expressions correctly evaluates to `True` if the person is old enough to drive but **not** old enough to vote?
#
# I. `(age >= 16) and (age <= 18)`
# II. `(age >= 16) and (not (age >= 18))`
# III. `(age < 18) and (not (age < 16))`
#
# - Circle all correct answers.
# - Explain briefly why.
#
# ---

# %% [markdown]
# <!doctype html>
# <html lang="en">
# <head>
#   <meta charset="utf-8" />
#   <meta name="viewport" content="width=device-width,initial-scale=1" />
#   <title>AP CSP — 10 Minute Problem Set (Boolean Expressions & Logic)</title>
#   <style>
#     :root{--bg:#f7fafc;--card:#fff;--accent:#2563eb;--muted:#6b7280}
#     body{font-family:system-ui,-apple-system,Segoe UI,Roboto,"Helvetica Neue",Arial;
#          background:var(--bg); color:#0f172a; margin:0; padding:28px;}
#     .container{max-width:860px;margin:0 auto;}
#     header{display:flex;align-items:center;gap:16px;margin-bottom:18px}
#     h1{font-size:1.25rem;margin:0}
#     p.lead{margin:0;color:var(--muted)}
#     .card{background:var(--card);border-radius:12px;padding:18px;box-shadow:0 6px 18px rgba(2,6,23,0.06);margin-bottom:14px;}
#     .q-title{font-weight:700;margin:0 0 8px 0}
#     .row{display:flex;gap:12px;flex-wrap:wrap}
#     label.option{display:inline-flex;align-items:center;gap:8px;padding:8px 10px;border-radius:8px;border:1px solid #e6edf8;cursor:pointer}
#     input[type="radio"], input[type="checkbox"]{transform:scale(1.05)}
#     textarea, input[type="text"], select{width:100%;padding:8px;border-radius:8px;border:1px solid #e6edf8;font-size:0.95rem}
#     .small{font-size:0.9rem;color:var(--muted)}
#     .actions{display:flex;gap:8px;margin-top:12px}
#     button{background:var(--accent);color:white;border:none;padding:8px 12px;border-radius:8px;cursor:pointer}
#     button.secondary{background:#f1f5f9;color:#0f172a}
#     pre{background:#0b1221;color:#f8fafc;padding:12px;border-radius:8px;overflow:auto}
#     .answer-key{display:none;margin-top:12px;background:#f8fafc;padding:12px;border-radius:8px;border:1px dashed #c7d2fe}
#     .result{margin-top:10px;padding:8px;border-radius:8px}
#     .correct{background:#ecfdf5;color:#065f46}
#     .incorrect{background:#fff1f2;color:#9f1239}
#   </style>
# </head>
# <body>
#   <div class="container">
#     <header>
#       <h1>AP CSP — 10 Minute Problem Set</h1>
#       <div style="margin-left:auto;text-align:right">
#         <div class="small">Big Idea 3.5 • Boolean Expressions & Logic</div>
#         <div class="small">Estimated time: 10 minutes</div>
#       </div>
#     </header>
#
#     <!-- 1. Boolean Basics -->
#     <section class="card" id="q1">
#       <p class="q-title">1. Boolean Basics (1 min) — Circle True or False</p>
#       <div class="small">a) A Boolean value can only be <code>True</code> or <code>False</code>.</div>
#       <div class="row" style="margin:6px 0 10px 0">
#         <label class="option"><input type="radio" name="q1a" value="True"> True</label>
#         <label class="option"><input type="radio" name="q1a" value="False"> False</label>
#       </div>
#
#       <div class="small">b) The expression <code>7 == 8</code> evaluates to <code>True</code>.</div>
#       <div class="row" style="margin:6px 0 10px 0">
#         <label class="option"><input type="radio" name="q1b" value="True"> True</label>
#         <label class="option"><input type="radio" name="q1b" value="False"> False</label>
#       </div>
#
#       <div class="small">c) The expression <code>5 &lt; 10</code> evaluates to <code>True</code>.</div>
#       <div class="row" style="margin:6px 0 4px 0">
#         <label class="option"><input type="radio" name="q1c" value="True"> True</label>
#         <label class="option"><input type="radio" name="q1c" value="False"> False</label>
#       </div>
#     </section>
#
#     <!-- 2. Relational Operators -->
#     <section class="card" id="q2">
#       <p class="q-title">2. Relational Operators (1 min)</p>
#       <div class="small">Fill in the blank with the correct relational operator (<code>==, !=, &gt;, &lt;, &gt;=, &lt;=</code>):</div>
#
#       <ol style="padding-left:18px;margin-top:8px">
#         <li style="margin-bottom:10px">
#           <div class="small"><code>8 ___ 8</code> → True</div>
#           <select id="q2a">
#             <option value="">— select —</option>
#             <option value="==">==</option>
#             <option value="!=">!=</option>
#             <option value="&gt;">&gt;</option>
#             <option value="&lt;">&lt;</option>
#             <option value="&gt;=">&gt;=</option>
#             <option value="&lt;=">&lt;=</option>
#           </select>
#         </li>
#
#         <li style="margin-bottom:10px">
#           <div class="small"><code>12 ___ 15</code> → True</div>
#           <select id="q2b">
#             <option value="">— select —</option>
#             <option value="==">==</option>
#             <option value="!=">!=</option>
#             <option value="&gt;">&gt;</option>
#             <option value="&lt;">&lt;</option>
#             <option value="&gt;=">&gt;=</option>
#             <option value="&lt;=">&lt;=</option>
#           </select>
#         </li>
#
#         <li style="margin-bottom:6px">
#           <div class="small"><code>5 ___ 2</code> → False</div>
#           <select id="q2c">
#             <option value="">— select —</option>
#             <option value="==">==</option>
#             <option value="!=">!=</option>
#             <option value="&gt;">&gt;</option>
#             <option value="&lt;">&lt;</option>
#             <option value="&gt;=">&gt;=</option>
#             <option value="&lt;=">&lt;=</option>
#           </select>
#         </li>
#       </ol>
#     </section>
#
#     <!-- 3. Modulo -->
#     <section class="card" id="q3">
#       <p class="q-title">3. Modulo Operator (1 min)</p>
#       <div class="small">Write a Boolean expression that checks if a variable <code>num</code> is <strong>even</strong>.</div>
#       <input id="q3" type="text" placeholder="Example: num % 2 == 0">
#       <div class="small" style="margin-top:8px">Example answer (click "Show Answers" to reveal): <code>num % 2 == 0</code></div>
#     </section>
#
#     <!-- 4. Logical Operators -->
#     <section class="card" id="q4">
#       <p class="q-title">4. Logical Operators (2 min)</p>
#       <div class="small">Determine if each expression is True or False when <code>x = 12</code> and <code>y = 5</code>.</div>
#
#       <ol style="padding-left:18px;margin-top:8px">
#         <li style="margin-bottom:8px">
#           <div class="small"><code>(x &gt; 10) and (y &gt; 10)</code> → ______</div>
#           <label class="option"><input type="radio" name="q4a" value="True"> True</label>
#           <label class="option"><input type="radio" name="q4a" value="False"> False</label>
#         </li>
#
#         <li style="margin-bottom:8px">
#           <div class="small"><code>(x &lt; 20) or (y &gt; 10)</code> → ______</div>
#           <label class="option"><input type="radio" name="q4b" value="True"> True</label>
#           <label class="option"><input type="radio" name="q4b" value="False"> False</label>
#         </li>
#
#         <li style="margin-bottom:6px">
#           <div class="small"><code>not (y &lt; 7)</code> → ______</div>
#           <label class="option"><input type="radio" name="q4c" value="True"> True</label>
#           <label class="option"><input type="radio" name="q4c" value="False"> False</label>
#         </li>
#       </ol>
#     </section>
#
#     <!-- 5. Scenario Practice -->
#     <section class="card" id="q5">
#       <p class="q-title">5. Scenario Practice (2 min)</p>
#       <div class="small">Write Boolean expressions for the following (type your answer or leave blank to check the example later):</div>
#
#       <ol style="padding-left:18px;margin-top:8px">
#         <li style="margin-bottom:10px">
#           <div class="small">a) You can go out if you finished your homework <strong>and</strong> your test score is at least 80.</div>
#           <input id="q5a" type="text" placeholder='Example: finished_homework and (test_score >= 80)'>
#         </li>
#
#         <li style="margin-bottom:6px">
#           <div class="small">b) You can leave your umbrella at home if it is <strong>not</strong> cloudy <strong>and</strong> the temperature is greater than 75.</div>
#           <input id="q5b" type="text" placeholder='Example: (not cloudy) and (temperature &gt; 75)'>
#         </li>
#       </ol>
#     </section>
#
#     <!-- 6. AP-Style -->
#     <section class="card" id="q6">
#       <p class="q-title">6. AP-Style Question (3 min)</p>
#       <div class="small">In a country, a person must be at least 16 years old to drive a car and at least 18 years old to vote. The variable <code>age</code> represents a person’s age.</div>
#
#       <div style="margin-top:8px" class="small">
#         Which of the following expressions correctly evaluates to <code>True</code> if the person is old enough to <strong>drive</strong> but <strong>not</strong> old enough to <strong>vote</strong>?
#       </div>
#
#       <ol style="padding-left:18px;margin-top:8px">
#         <li style="margin-bottom:6px"><label><input type="checkbox" id="ap1"> I. <code>(age &gt;= 16) and (age &lt;= 18)</code></label></li>
#         <li style="margin-bottom:6px"><label><input type="checkbox" id="ap2"> II. <code>(age &gt;= 16) and (not (age &gt;= 18))</code></label></li>
#         <li style="margin-bottom:6px"><label><input type="checkbox" id="ap3"> III. <code>(age &lt; 18) and (not (age &lt; 16))</code></label></li>
#       </ol>
#
#       <div class="small" style="margin-top:8px">Circle all correct answers and briefly explain why.</div>
#       <textarea id="ap-explain" rows="3" placeholder="Write a short explanation..."></textarea>
#     </section>
#
#     <div class="actions">
#       <button id="checkBtn">Check selected answers</button>
#       <button class="secondary" id="showBtn">Show answers / Example solutions</button>
#       <button class="secondary" id="resetBtn">Reset</button>
#     </div>
#
#     <div id="output" style="margin-top:12px"></div>
#
#     <div class="card small" style="margin-top:18px">
#       Tip: this page is ready to copy & paste into a file (save as <code>apcsp_booleans.html</code>). Use it in class as a quick formative check or a ten-minute warm-up.
#     </div>
#
#     <!-- Answer key (hidden by default) -->
#     <div class="answer-key" id="answerKey">
#       <strong>Answer Key / Example Solutions</strong>
#       <ol style="margin-top:8px">
#         <li><strong>Boolean Basics</strong>: (a) True, (b) False, (c) True</li>
#         <li><strong>Relational Operators</strong>: (a) <code>==</code>, (b) <code>&lt;</code>, (c) <code>&gt;</code></li>
#         <li><strong>Modulo</strong>: <code>num % 2 == 0</code></li>
#         <li><strong>Logical Operators (x=12, y=5)</strong>:
#           <ul>
#             <li>(x &gt; 10) and (y &gt; 10) → <em>False</em></li>
#             <li>(x &lt; 20) or (y &gt; 10) → <em>True</em></li>
#             <li>not (y &lt; 7) → <em>False</em></li>
#           </ul>
#         </li>
#         <li><strong>Scenario Practice</strong>:
#           <ul>
#             <li>a) <code>finished_homework and (test_score &gt;= 80)</code></li>
#             <li>b) <code>(not cloudy) and (temperature &gt; 75)</code></li>
#           </ul>
#         </li>
#         <li><strong>AP-Style</strong>: Correct answers are <strong>II</strong> and <strong>III</strong>.
#           <div class="small" style="margin-top:6px">
#             Explanation: "Old enough to drive but not to vote" means <code>16 &le; age &lt; 18</code>.
#             II expands to <code>age &gt;= 16 and age &lt; 18</code>.
#             III is equivalent to the same condition. I is incorrect because it allows <code>age == 18</code>, which would be old enough to vote.
#           </div>
#         </li>
#       </ol>
#     </div>
#   </div>
#
#   <script>
#     // Basic auto-checker for the multiple-choice parts and AP question.
#     function showMessage(html, className) {
#       const out = document.getElementById('output');
#       out.innerHTML = '<div class="result '+className+'">'+html+'</div>';
#     }
#
#     function checkAnswers(){
#       // Q1 answers
#       const q1a = document.querySelector('input[name="q1a"]:checked')?.value;
#       const q1b = document.querySelector('input[name="q1b"]:checked')?.value;
#       const q1c = document.querySelector('input[name="q1c"]:checked')?.value;
#
#       // Q2
#       const q2a = document.getElementById('q2a').value;
#       const q2b = document.getElementById('q2b').value;
#       const q2c = document.getElementById('q2c').value;
#
#       // Q4
#       const q4a = document.querySelector('input[name="q4a"]:checked')?.value;
#       const q4b = document.querySelector('input[name="q4b"]:checked')?.value;
#       const q4c = document.querySelector('input[name="q4c"]:checked')?.value;
#
#       // AP
#       const ap1 = document.getElementById('ap1').checked;
#       const ap2 = document.getElementById('ap2').checked;
#       const ap3 = document.getElementById('ap3').checked;
#
#       // Evaluate correctness
#       let correct = 0, total = 0;
#       // Q1: three items
#       total += 3;
#       if (q1a === 'True') correct++;
#       if (q1b === 'False') correct++;
#       if (q1c === 'True') correct++;
#
#       // Q2: three items
#       total += 3;
#       if (q2a === '==') correct++;
#       if (q2b === '<') correct++;
#       if (q2c === '>') correct++;
#
#       // Q4: three items
#       total += 3;
#       if (q4a === 'False') correct++;
#       if (q4b === 'True') correct++;
#       if (q4c === 'False') correct++;
#
#       // AP: checkboxes (II and III correct; I incorrect)
#       total += 1;
#       if (ap2 && ap3 && !ap1) correct++;
#
#       // Show summary
#       const pct = Math.round((correct/total)*100);
#       let msg = `<strong>Score: ${correct} / ${total} (${pct}%)</strong><br>`;
#       msg += `<div style="margin-top:6px">✔️ Correct answers checked automatically for multiple-choice & AP checkbox question. For written responses (Q3 & Q5) click "Show answers" to compare examples.</div>`;
#       showMessage(msg, pct >= 70 ? 'correct' : 'incorrect');
#     }
#
#     document.getElementById('checkBtn').addEventListener('click', function(){
#       checkAnswers();
#       // also reveal which AP checkboxes are wrong/correct
#       const ap1 = document.getElementById('ap1');
#       const ap2 = document.getElementById('ap2');
#       const ap3 = document.getElementById('ap3');
#       // Visual hint for AP selections:
#       ap1.nextSibling && (ap1.parentElement.style.opacity = ap1.checked ? '1' : '1');
#     });
#
#     document.getElementById('showBtn').addEventListener('click', function(){
#       const key = document.getElementById('answerKey');
#       key.style.display = key.style.display === 'block' ? 'none' : 'block';
#       // also scroll into view
#       if (key.style.display === 'block') key.scrollIntoView({behavior:'smooth'});
#     });
#
#     document.getElementById('resetBtn').addEventListener('click', function(){
#       document.querySelectorAll('input').forEach(i => {
#         if (i.type === 'radio' || i.type === 'checkbox') i.checked = false;
#         else i.value = '';
#       });
#       document.querySelectorAll('select').forEach(s => s.value = '');
#       document.querySelectorAll('textarea').forEach(t => t.value = '');
#       document.getElementById('output').innerHTML = '';
#       document.getElementById('answerKey').style.display = 'none';
#       window.scrollTo({top:0,behavior:'smooth'});
#     });
#   </script>
# </body>
# </html>

# %% [markdown]
# <!-- Boolean Expressions Problem Set -->
# <section class="wrap reveal" id="s-boolean">
#   <div class="panel">
#     <h2>💻 AP CSP – 10 Minute Problem Set</h2>
#     <p><strong>Big Idea 3.5:</strong> Boolean Expressions and Logic</p>
#     <ol>
#       <li>
#         <h3>Boolean Basics (1 min)</h3>
#         <p>Circle <code>True</code> or <code>False</code>:</p>
#         <ul>
#           <li>a) A Boolean value can only be <code>True</code> or <code>False</code>.</li>
#           <li>b) The expression <code>7 == 8</code> evaluates to <code>True</code>.</li>
#           <li>c) The expression <code>5 &lt; 10</code> evaluates to <code>True</code>.</li>
#         </ul>
#       </li>
#
#       <li>
#         <h3>Relational Operators (1 min)</h3>
#         <p>Fill in the blank with the correct relational operator (<code>&lt;</code>, <code>&gt;</code>, <code>==</code>, <code>!=</code>):</p>
#         <p><code>12 ____ 7</code></p>
#       </li>
#
#       <li>
#         <h3>Modulo Operator (2 min)</h3>
#         <p>Use the <code>%</code> operator:</p>
#         <ul>
#           <li>a) Write an expression to check if a number <code>x</code> is even.</li>
#           <li>b) Write an expression to check if a number <code>y</code> leaves remainder <code>3</code> when divided by <code>5</code>.</li>
#         </ul>
#       </li>
#
#       <li>
#         <h3>Practice Boolean Expressions (3 min)</h3>
#         <p>Write Boolean expressions for the following:</p>
#         <ul>
#           <li>a) Check if <code>num1</code> is odd.</li>
#           <li>b) Check if <code>temperature</code> is less than <code>90</code>.</li>
#           <li>c) Check if <code>score</code> is at least <code>70</code> and less than <code>100</code>.</li>
#         </ul>
#       </li>
#
#       <li>
#         <h3>Logical Operators (3 min)</h3>
#         <p>Use <code>not</code>, <code>and</code>, <code>or</code>:</p>
#         <ul>
#           <li>a) <code>isHungry = True</code>, <code>hasSnack = False</code> → What does <code>print(isHungry and hasSnack)</code> show?</li>
#           <li>b) Write an expression that is <code>True</code> if a student finished their homework <em>or</em> has extra credit.</li>
#           <li>c) Write an expression that is <code>False</code> if a number <code>n</code> is greater than 50.</li>
#         </ul>
#       </li>
#     </ol>
#   </div>
# </section>

# %% [raw]
# ---
# layout: post
# toc: True
# breadcrumb: True
# title: Vivian's Blog!
# description: My CSP Journey
# permalink: vivianblog
# author: Vivian Zhang
# ---

# %% [markdown]
# ## First Days in CSP
# - with little to no previous coding experience, I struggled during the first couple days especially because my computer wasn't updated to Sequoia, and the make command didn't work. But, I perservered.
#
# ## Commands I learned:
# - pwd: shows you which directory you're in
# - cd: changes your directory
# - ls: lists what's in your folder
# - mkdir: makes a new directory
#
# ## Helping Hands
# - I went to office hours and Mr. Mortensen cleared a lot of my confusion up. Our class TA's Avantika and Aadit were also a great help to my struggles.
#
# ## Collaboration
# - I've really enjoyed working with my team and working through road bumps together. Communication is key to a well-functioning team and I think we have been able to do that pretty well.
